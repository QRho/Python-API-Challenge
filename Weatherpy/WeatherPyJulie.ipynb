# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
cities
# Out:
# ['atuona',
#  'punta arenas',
#  'lebu',
#  'beresti-sat',
#  'cervo',
#  'bethel',
#  'jiangyou',
#  'bluff',
#  'cape town',
#  'dikson',
#  'ushuaia',
#  'avarua',
#  'ostrovnoy',
#  'bilma',
#  'beringovskiy',
#  'umm lajj',
#  'kaitangata',
#  'dukat',
#  'abha',
#  'severo-kurilsk',
#  'nikolskoye',
#  'mys shmidta',
#  'caravelas',
#  'saint-philippe',
#  'husavik',
#  'mahebourg',
#  'novikovo',
#  'mataura',
#  'kapaa',
#  'vaitupu',
#  'po',
#  'albertville',
#  'fangshan',
#  'raudeberg',
#  'tiznit',
#  'innisfail',
#  'lazaro cardenas',
#  'norman wells',
#  'carnarvon',
#  'ormond beach',
#  'labuhan',
#  'emerald',
#  'flin flon',
#  'hornepayne',
#  'nouadhibou',
#  'san patricio',
#  'hambantota',
#  'savannah bight',
#  'dombarovskiy',
#  'vila velha',
#  'abalak',
#  'bengkulu',
#  'rikitea',
#  'busselton',
#  'faanui',
#  'jamestown',
#  'luderitz',
#  'barrow',
#  'enumclaw',
#  'palmer',
#  'albany',
#  'taolanaro',
#  'tagusao',
#  'sassandra',
#  'hobart',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# # Loop through each character
# for City_ID in search_cities:
    
#     # Create search query, make request and store in json
#     query_url = url + City_ID + City
#     response = requests.get(query)
#     response_json = response.json()
  
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()

# %%
    
url = "http://api.openweathermap.org/data/2.5/weather?"

for city_id,city_name in enumerate (cities):
    print(city_id,city_name)
    
    query_url = url + "appid=" + weather_api_key + "&q=" + city_name
    print(query_url)
    
#     response = requests.get(query_url)
#     response_json = response.json()
  
#weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# Out:
# 0 atuona
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=atuona
# 1 punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=punta arenas
# 2 lebu
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=lebu
# 3 beresti-sat
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=beresti-sat
# 4 cervo
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=cervo
# 5 bethel
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=bethel
# 6 jiangyou
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=jiangyou
# 7 bluff
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=bluff
# 8 cape town
# http://api.openweathermap.org/data/2.5/weather?appid=998d69a67d344bb008012b691bc42eea&q=cape town
# ...

# %%
# City_ID = "City_ID"
# Each_City = "City"

# url = "http://api.openweathermap.org/data/2.5/weather?"


# #Build query URL
 
# query_url = url + "appid=" + weather_api_key + "&q=" + Each_City

# weather_response = requests.get(query_url)
# weather_json = weather_response.json()

#  # Get the temperature from the response
# print(f"Weather is: {weather_json}.")


# # api.openweathermap.org/data/2.5/weather?q={city name},{state},{country code}

# %%
# # List of character
# search_cities = ['Cities', 'City_ID']

# # Set url for API
# url = 'http://api.openweathermap.org/data/2.5/weather?'

# # Set empty lists to hold characters height and mass
# City_ID = []
# City = []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df=pd.read_csv("cities.csv")
cities_df
#cities_df.to_csv("CitiesPart1.csv")
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
Lat=cities_df["Lat"]
Maxtemp=cities_df["Max Temp"]
plt.scatter(Lat,Maxtemp,label="cities")
plt.title ("Latitude vs.Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
Lat=cities_df["Lat"]
Maxtemp=cities_df["Humidity"]
plt.scatter(Lat,Maxtemp,label="cities")
plt.title ("Latitude vs.Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
Lat=cities_df["Lat"]
Maxtemp=cities_df["Wind Speed"]
plt.scatter(Lat,Maxtemp,label="cities")
plt.title ("Latitude vs.Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
Lat=cities_df["Lat"]
Maxtemp=cities_df["Cloudiness"]
plt.scatter(Lat,Maxtemp,label="cities")
plt.title ("Latitude vs.Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def lineplot(x,y,ytitle):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = x* slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(ytitle)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north=cities_df.loc[(cities_df["Lat"]>=0)]
south=cities_df.loc[(cities_df["Lat"]<0)]

north
south
# Out:
#      City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 1          1  mahebourg          75      MU  1558378503        74 -20.41
# 4          4  cape town          20      ZA  1558378755        76 -33.93
# 5          5     atuona          78      PF  1558378755        76  -9.80
# 6          6   flinders           0      AU  1558378755        62 -34.58
# 7          7      opuwo           0     NaN  1558378523        23 -18.06
# ..       ...        ...         ...     ...         ...       ...    ...
# 526      526     viedma          14      AR  1558378894        41 -40.81
# 531      531    russell          75      AR  1558378895        71 -33.01
# 536      536     padang         100      ID  1558378896        82  -0.92
# 539      539       palu          72      ID  1558378897        80  -0.90
# 541      541   tamworth          64      AU  1558378897        87 -31.09
#
#         Lng  Max Temp  Wind Speed
# 1     57.70     78.80       11.41
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x=north["Lat"]
y=north["Max Temp"]
lineplot(x,y,"Max Temp")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x=south["Lat"]
y=south["Max Temp"]
lineplot(x,y,"Max Temp")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=north["Lat"]
y=north["Humidity"]
lineplot(x,y,"Humidity")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=south["Lat"]
y=south["Humidity"]
lineplot(x,y,"Humidity")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=north["Lat"]
y=north["Cloudiness"]
lineplot(x,y,"Cloudiness")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=south["Lat"]
y=south["Cloudiness"]
lineplot(x,y,"Cloudiness")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x=north["Lat"]
y=north["Wind Speed"]
lineplot(x,y,"Wind Speed")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x=south["Lat"]
y=south["Wind Speed"]
lineplot(x,y,"Wind Speed")
